# %%
import pandas as pd
from pathlib import Path

# %%
three_sec_orignial_df = pd.read_csv(Path('Resources/fma_3secs.csv'))
#three_sec_orignial_df

# %%
thirty_sec_orignial_df = pd.read_csv(Path('Resources/fma_30secs.csv'))

# %%
true_data_3sec = three_sec_orignial_df.sample(frac = 0.1, random_state=1)
true_data_3sec.to_csv('Resources/true_data_3sec.csv')

# %%
model_data_3sec = three_sec_orignial_df.drop(true_data_3sec.index)
model_data_3sec.to_csv('Resources/model_data_3sec.csv')

# %%
true_data_3sec
# Out:
#             filename  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 60722   3-123979.mp3          0.276626         0.086329  0.108116  0.001194
# 36465   6-081660.mp3          0.234759         0.080489  0.047486  0.000063
# 65771   2-128813.mp3          0.291566         0.087549  0.088084  0.000447
# 33210   1-073658.mp3          0.239453         0.085738  0.081056  0.001369
# 1694    5-006779.mp3          0.247186         0.086972  0.061834  0.001099
# ...              ...               ...              ...       ...       ...
# 36919  10-082929.mp3          0.373331         0.078668  0.107726  0.000859
# 37563   4-084054.mp3          0.308779         0.068659  0.132966  0.000132
# 37783   4-085956.mp3          0.418342         0.075610  0.262002  0.001339
# 76801   2-145727.mp3          0.546905         0.066876  0.198069  0.001233
# 211     2-000892.mp3          0.263603         0.080143  0.265479  0.000430
#
# ...

# %%
model_data_3sec
# Out:
#             filename  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0       1-000574.mp3          0.381544         0.080175  0.249562  0.001513
# 2       3-000574.mp3          0.484288         0.069135  0.253424  0.001391
# 3       4-000574.mp3          0.425569         0.074970  0.256628  0.001596
# 4       5-000574.mp3          0.468948         0.066816  0.265448  0.001309
# 5       6-000574.mp3          0.392290         0.079841  0.271375  0.001388
# ...              ...               ...              ...       ...       ...
# 79935   6-155066.mp3          0.457243         0.066993  0.243057  0.000386
# 79936   7-155066.mp3          0.447897         0.071476  0.234766  0.000319
# 79937   8-155066.mp3          0.444989         0.068753  0.230987  0.000125
# 79938   9-155066.mp3          0.485998         0.070497  0.233158  0.000335
# 79939  10-155066.mp3          0.528556         0.065992  0.244644  0.000123
#
# ...
