# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#url = 'Resources/fma_3secs.csv'
orignial_df = pd.read_csv(Path('Resources/model_data_3sec.csv'))
orignial_df
# Out:
#        Unnamed: 0       filename  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0               0   1-000574.mp3          0.381544         0.080175  0.249562
# 1               2   3-000574.mp3          0.484288         0.069135  0.253424
# 2               3   4-000574.mp3          0.425569         0.074970  0.256628
# 3               4   5-000574.mp3          0.468948         0.066816  0.265448
# 4               5   6-000574.mp3          0.392290         0.079841  0.271375
# ...           ...            ...               ...              ...       ...
# 71941       79935   6-155066.mp3          0.457243         0.066993  0.243057
# 71942       79936   7-155066.mp3          0.447897         0.071476  0.234766
# 71943       79937   8-155066.mp3          0.444989         0.068753  0.230987
# 71944       79938   9-155066.mp3          0.485998         0.070497  0.233158
# 71945       79939  10-155066.mp3          0.528556         0.065992  0.244644
#
#         rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0      0.001513             1957.407156           39590.736312
# 1      0.001391             2766.351306          309436.169216
# 2      0.001596             2908.207536          157800.863917
# 3      0.001309             2618.340173          129314.679539
# 4      0.001388             2767.550410          159341.482509
# ...         ...                     ...                    ...
# 71941  0.000386              483.225740           45172.684403
# 71942  0.000319              660.113748          112158.840869
# 71943  0.000125              631.195340          129673.607382
# 71944  0.000335              616.469137          113308.485962
# 71945  0.000123              545.420500           67017.816112
#
#        spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0                  2048.485350            25901.153997  ...   30.766535
# 1                  2542.654962           168310.924937  ...   25.085670
# 2                  2703.913526            39721.816727  ...   21.063715
# 3                  2548.584807            34028.788419  ...   23.539871
# 4                  2663.721676            52306.024210  ...   30.794027
# ...                        ...                     ...  ...         ...
# 71941               875.708502           266648.246421  ...   44.069397
# 71942              1349.132689           567015.357017  ...   94.042519
# 71943              1317.927939           579189.561418  ...   42.242142
# 71944              1299.877639           574072.621801  ...   32.535034
# 71945               941.891814           426029.234685  ...   86.490700
#
#        mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0        -8.990259   43.198818     1.595329   27.528227    -6.731744
# 1        -7.587147   42.912727     0.172193   30.070772    -5.444875
# 2        -8.594354   15.883783    -0.271126   27.283262    -5.592191
# 3        -9.315182   17.867613    -3.543423   15.073790    -5.760088
# 4        -8.423706   22.058167    -0.152457   19.684511    -4.535352
# ...            ...         ...          ...         ...          ...
# 71941     4.513030   35.256451     4.309551   25.806019     9.335838
# 71942     1.916095   32.742737     2.931519   26.395258     7.093570
# 71943     4.368050   34.333134     4.368290   35.798908     7.466063
# 71944     1.273448   29.834116     4.322249   15.078435     9.085366
# 71945     8.151299   23.870853     8.260559   24.871418     6.523771
#
#        mfcc19_var  mfcc20_mean  mfcc20_var    label
# 0       34.697533     4.317326   35.314476     Rock
# 1       14.732526     1.197923   23.562773     Rock
# 2       24.557570    -0.288590   14.412757     Rock
# 3       25.771444     2.120627   32.800819     Rock
# 4       17.765066     2.383680   14.638711     Rock
# ...           ...          ...         ...      ...
# 71941   30.525654     4.856527   22.975540  Hip-Hop
# 71942   41.896832     5.723800   27.765524  Hip-Hop
# 71943   37.081589     1.732873   36.141926  Hip-Hop
# 71944   24.073069     6.584610   37.525909  Hip-Hop
# 71945   45.176666     3.882302   26.079874  Hip-Hop
#
# [71946 rows x 60 columns]

# %%
orignial_df.isnull().values.any()
# Out:
# False

# %%
#drop label and filename columns
X = orignial_df.drop(['Unnamed: 0','label','filename'], axis=1)
# get label values 
y = orignial_df['label']
y.unique()
# Out:
# array(['Rock', 'Folk', 'Experimental', 'Hip-Hop', 'International', 'Pop',
#        'Electronic', 'Instrumental'], dtype=object)

# %%
#check if data is balanced
pd.DataFrame(y)['label'].value_counts()
# Out:
# Pop              9025
# Hip-Hop          9022
# Folk             9017
# International    9005
# Instrumental     8998
# Experimental     8971
# Rock             8965
# Electronic       8943
# Name: label, dtype: int64

# %%
X = X[X.columns.drop(list(X.filter(regex='var')))]
X
# Out:
#        chroma_stft_mean  rms_mean  spectral_centroid_mean  \
# 0              0.381544  0.249562             1957.407156
# 1              0.484288  0.253424             2766.351306
# 2              0.425569  0.256628             2908.207536
# 3              0.468948  0.265448             2618.340173
# 4              0.392290  0.271375             2767.550410
# ...                 ...       ...                     ...
# 71941          0.457243  0.243057              483.225740
# 71942          0.447897  0.234766              660.113748
# 71943          0.444989  0.230987              631.195340
# 71944          0.485998  0.233158              616.469137
# 71945          0.528556  0.244644              545.420500
#
#        spectral_bandwidth_mean  rolloff_mean  zero_crossing_rate_mean  \
# 0                  2048.485350   3585.029860                 0.100943
# 1                  2542.654962   5738.018893                 0.158905
# 2                  2703.913526   6252.910907                 0.163713
# 3                  2548.584807   5554.903846                 0.139870
# 4                  2663.721676   5940.845102                 0.146143
# ...                        ...           ...                      ...
# 71941               875.708502    703.804462                 0.019449
# 71942              1349.132689    775.692233                 0.019035
# 71943              1317.927939    887.664889                 0.014461
# 71944              1299.877639    730.638146                 0.018412
# 71945               941.891814    782.289585                 0.015856
#
#        harmony_mean  perceptr_mean       tempo  mfcc1_mean  ...  mfcc11_mean  \
# 0          0.000052       0.000068  112.347147   -8.945985  ...     3.019332
# 1          0.000034      -0.000009  117.453835   31.914341  ...    -3.049455
# 2          0.000011      -0.000250  117.453835   36.925098  ...    -5.784952
# 3         -0.000049      -0.000192  123.046875   37.924717  ...    -8.235471
# 4         -0.000054      -0.000268  117.453835   37.417984  ...     2.061754
# ...             ...            ...         ...         ...  ...          ...
# 71941      0.000010      -0.000006  135.999178 -278.415741  ...    -1.636234
# 71942     -0.000303       0.000336  135.999178 -273.169312  ...    -3.726220
# 71943      0.000217      -0.000002  135.999178 -277.834869  ...    -3.057849
# 71944     -0.000048       0.000080  135.999178 -284.960388  ...    -3.458435
# 71945     -0.000032       0.000376  135.999178 -261.417267  ...     0.141129
#
#        mfcc12_mean  mfcc13_mean  mfcc14_mean  mfcc15_mean  mfcc16_mean  \
# 0         3.665317    -9.748421     2.995540    -4.559982    -2.866331
# 1         2.144493    -9.148898     4.389838    -6.054724    -3.617906
# 2         3.680824   -10.186584     2.543274    -6.967072    -2.589857
# 3         1.791170    -8.883386    -0.221089    -7.038162    -2.001146
# 4        -0.329844    -7.563095     4.706252    -5.521904    -4.830932
# ...            ...          ...          ...          ...          ...
# 71941     6.133297     4.796370     2.530937     7.792923    14.952423
# 71942     7.489089     2.066535     1.700049     2.323061     7.850317
# 71943     6.231783     3.418291     4.423429     6.805921    10.383173
# 71944     7.796859     3.189467     2.171970     2.082361     6.422930
# 71945     1.875216    -1.231963     4.126509     4.054971     6.435394
#
#        mfcc17_mean  mfcc18_mean  mfcc19_mean  mfcc20_mean
# 0        -8.990259     1.595329    -6.731744     4.317326
# 1        -7.587147     0.172193    -5.444875     1.197923
# 2        -8.594354    -0.271126    -5.592191    -0.288590
# 3        -9.315182    -3.543423    -5.760088     2.120627
# 4        -8.423706    -0.152457    -4.535352     2.383680
# ...            ...          ...          ...          ...
# 71941     4.513030     4.309551     9.335838     4.856527
# 71942     1.916095     2.931519     7.093570     5.723800
# 71943     4.368050     4.368290     7.466063     1.732873
# 71944     1.273448     4.322249     9.085366     6.584610
# 71945     8.151299     8.260559     6.523771     3.882302
#
# [71946 rows x 29 columns]

# %% [markdown]
# import seaborn as sns
# sns.pairplot(X)

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (71946, 29) (71946,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### With unscaled data

# %%
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.32242999314294185
# Testing Data Score: 0.3225107021737922
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction         Actual
# 48644   Instrumental   Instrumental
# 66377        Hip-Hop        Hip-Hop
# 23285           Folk        Hip-Hop
# 44308   Instrumental   Experimental
# 44043  International  International
# ...              ...            ...
# 3380         Hip-Hop        Hip-Hop
# 12605        Hip-Hop     Electronic
# 20662           Folk     Electronic
# 14804           Folk           Rock
# 18430  International            Pop
#
# [17987 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.27      0.23      0.25      2251
#  Experimental       0.25      0.15      0.18      2232
#          Folk       0.33      0.46      0.38      2262
#       Hip-Hop       0.35      0.42      0.38      2252
#  Instrumental       0.39      0.48      0.43      2231
# International       0.33      0.24      0.28      2292
#           Pop       0.15      0.05      0.08      2270
#          Rock       0.33      0.57      0.42      2197
#
#      accuracy                           0.32     17987
#     macro avg       0.30      0.32      0.30     17987
#  weighted avg       0.30      0.32      0.30     17987

# %% [markdown]
# ### With Scaled Data

# %%
# Create a StandardScaler() model and fit it to the training data
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train_scaled, y_train)
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.41147908597268296
# Testing Data Score: 0.413965641852449
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
predictions = classifier.predict(X_test_scaled)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction         Actual
# 48644   Instrumental   Instrumental
# 66377        Hip-Hop        Hip-Hop
# 23285           Folk        Hip-Hop
# 44308  International   Experimental
# 44043  International  International
# ...              ...            ...
# 3380         Hip-Hop        Hip-Hop
# 12605     Electronic     Electronic
# 20662        Hip-Hop     Electronic
# 14804            Pop           Rock
# 18430  International            Pop
#
# [17987 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
y_pred = classifier.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.39      0.41      0.40      2251
#  Experimental       0.35      0.21      0.26      2232
#          Folk       0.44      0.57      0.50      2262
#       Hip-Hop       0.46      0.52      0.49      2252
#  Instrumental       0.45      0.47      0.46      2231
# International       0.39      0.36      0.37      2292
#           Pop       0.26      0.12      0.17      2270
#          Rock       0.43      0.66      0.52      2197
#
#      accuracy                           0.41     17987
#     macro avg       0.40      0.41      0.40     17987
#  weighted avg       0.40      0.41      0.40     17987

# %%
from joblib import dump, load
dump(classifier, 'Model/3_sec_model_LR.joblib')
# Out:
# ['Model/3_sec_model_LR.joblib']
