# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#url = 'Resources/fma_3secs.csv'
orignial_df = pd.read_csv(Path('Resources/fma_3secs.csv'))
orignial_df
# Out:
#             filename  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0       1-000574.mp3          0.381544         0.080175  0.249562  0.001513
# 1       2-000574.mp3          0.436518         0.074070  0.263343  0.001272
# 2       3-000574.mp3          0.484288         0.069135  0.253424  0.001391
# 3       4-000574.mp3          0.425569         0.074970  0.256628  0.001596
# 4       5-000574.mp3          0.468948         0.066816  0.265448  0.001309
# ...              ...               ...              ...       ...       ...
# 79935   6-155066.mp3          0.457243         0.066993  0.243057  0.000386
# 79936   7-155066.mp3          0.447897         0.071476  0.234766  0.000319
# 79937   8-155066.mp3          0.444989         0.068753  0.230987  0.000125
# 79938   9-155066.mp3          0.485998         0.070497  0.233158  0.000335
# 79939  10-155066.mp3          0.528556         0.065992  0.244644  0.000123
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                 1957.407156           39590.736312              2048.485350
# 1                 1969.829480           75422.537033              2031.262553
# 2                 2766.351306          309436.169216              2542.654962
# 3                 2908.207536          157800.863917              2703.913526
# 4                 2618.340173          129314.679539              2548.584807
# ...                       ...                    ...                      ...
# 79935              483.225740           45172.684403               875.708502
# 79936              660.113748          112158.840869              1349.132689
# 79937              631.195340          129673.607382              1317.927939
# 79938              616.469137          113308.485962              1299.877639
# 79939              545.420500           67017.816112               941.891814
#
#        spectral_bandwidth_var  rolloff_mean  ...  mfcc16_var  mfcc17_mean  \
# 0                25901.153997   3585.029860  ...   30.766535    -8.990259
# 1                55656.387528   3668.926532  ...   34.857918    -7.328859
# 2               168310.924937   5738.018893  ...   25.085670    -7.587147
# 3                39721.816727   6252.910907  ...   21.063715    -8.594354
# 4                34028.788419   5554.903846  ...   23.539871    -9.315182
# ...                       ...           ...  ...         ...          ...
# 79935           266648.246421    703.804462  ...   44.069397     4.513030
# 79936           567015.357017    775.692233  ...   94.042519     1.916095
# 79937           579189.561418    887.664889  ...   42.242142     4.368050
# 79938           574072.621801    730.638146  ...   32.535034     1.273448
# 79939           426029.234685    782.289585  ...   86.490700     8.151299
#
#        mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0       43.198818     1.595329   27.528227    -6.731744   34.697533
# 1       30.140669     0.171362   23.946671    -5.767624   31.231506
# 2       42.912727     0.172193   30.070772    -5.444875   14.732526
# 3       15.883783    -0.271126   27.283262    -5.592191   24.557570
# 4       17.867613    -3.543423   15.073790    -5.760088   25.771444
# ...           ...          ...         ...          ...         ...
# 79935   35.256451     4.309551   25.806019     9.335838   30.525654
# 79936   32.742737     2.931519   26.395258     7.093570   41.896832
# 79937   34.333134     4.368290   35.798908     7.466063   37.081589
# 79938   29.834116     4.322249   15.078435     9.085366   24.073069
# 79939   23.870853     8.260559   24.871418     6.523771   45.176666
#
#        mfcc20_mean  mfcc20_var    label
# 0         4.317326   35.314476     Rock
# 1         3.249825   28.855471     Rock
# 2         1.197923   23.562773     Rock
# 3        -0.288590   14.412757     Rock
# 4         2.120627   32.800819     Rock
# ...            ...         ...      ...
# 79935     4.856527   22.975540  Hip-Hop
# 79936     5.723800   27.765524  Hip-Hop
# 79937     1.732873   36.141926  Hip-Hop
# 79938     6.584610   37.525909  Hip-Hop
# 79939     3.882302   26.079874  Hip-Hop
#
# [79940 rows x 59 columns]

# %%
orignial_df.isnull().values.any()
# Out:
# False

# %%
#drop label and filename columns
X = orignial_df.drop(['label','filename'], axis=1)
# get label values 
y = orignial_df['label']
y.unique()
# Out:
# array(['Rock', 'Folk', 'Experimental', 'Hip-Hop', 'International', 'Pop',
#        'Electronic', 'Instrumental'], dtype=object)

# %%
#check if data is balanced
pd.DataFrame(y)['label'].value_counts()
# Out:
# Instrumental     10000
# International    10000
# Folk             10000
# Pop              10000
# Rock              9990
# Electronic        9990
# Experimental      9990
# Hip-Hop           9970
# Name: label, dtype: int64

# %%
X = X[X.columns.drop(list(X.filter(regex='var')))]
X
# Out:
#        chroma_stft_mean  rms_mean  spectral_centroid_mean  \
# 0              0.381544  0.249562             1957.407156
# 1              0.436518  0.263343             1969.829480
# 2              0.484288  0.253424             2766.351306
# 3              0.425569  0.256628             2908.207536
# 4              0.468948  0.265448             2618.340173
# ...                 ...       ...                     ...
# 79935          0.457243  0.243057              483.225740
# 79936          0.447897  0.234766              660.113748
# 79937          0.444989  0.230987              631.195340
# 79938          0.485998  0.233158              616.469137
# 79939          0.528556  0.244644              545.420500
#
#        spectral_bandwidth_mean  rolloff_mean  zero_crossing_rate_mean  \
# 0                  2048.485350   3585.029860                 0.100943
# 1                  2031.262553   3668.926532                 0.105416
# 2                  2542.654962   5738.018893                 0.158905
# 3                  2703.913526   6252.910907                 0.163713
# 4                  2548.584807   5554.903846                 0.139870
# ...                        ...           ...                      ...
# 79935               875.708502    703.804462                 0.019449
# 79936              1349.132689    775.692233                 0.019035
# 79937              1317.927939    887.664889                 0.014461
# 79938              1299.877639    730.638146                 0.018412
# 79939               941.891814    782.289585                 0.015856
#
#        harmony_mean  perceptr_mean       tempo  mfcc1_mean  ...  mfcc11_mean  \
# 0          0.000052       0.000068  112.347147   -8.945985  ...     3.019332
# 1          0.000015      -0.000064  123.046875    7.491493  ...     0.169190
# 2          0.000034      -0.000009  117.453835   31.914341  ...    -3.049455
# 3          0.000011      -0.000250  117.453835   36.925098  ...    -5.784952
# 4         -0.000049      -0.000192  123.046875   37.924717  ...    -8.235471
# ...             ...            ...         ...         ...  ...          ...
# 79935      0.000010      -0.000006  135.999178 -278.415741  ...    -1.636234
# 79936     -0.000303       0.000336  135.999178 -273.169312  ...    -3.726220
# 79937      0.000217      -0.000002  135.999178 -277.834869  ...    -3.057849
# 79938     -0.000048       0.000080  135.999178 -284.960388  ...    -3.458435
# 79939     -0.000032       0.000376  135.999178 -261.417267  ...     0.141129
#
#        mfcc12_mean  mfcc13_mean  mfcc14_mean  mfcc15_mean  mfcc16_mean  \
# 0         3.665317    -9.748421     2.995540    -4.559982    -2.866331
# 1         4.600701    -7.535604     2.267977    -6.112905    -5.193264
# 2         2.144493    -9.148898     4.389838    -6.054724    -3.617906
# 3         3.680824   -10.186584     2.543274    -6.967072    -2.589857
# 4         1.791170    -8.883386    -0.221089    -7.038162    -2.001146
# ...            ...          ...          ...          ...          ...
# 79935     6.133297     4.796370     2.530937     7.792923    14.952423
# 79936     7.489089     2.066535     1.700049     2.323061     7.850317
# 79937     6.231783     3.418291     4.423429     6.805921    10.383173
# 79938     7.796859     3.189467     2.171970     2.082361     6.422930
# 79939     1.875216    -1.231963     4.126509     4.054971     6.435394
#
#        mfcc17_mean  mfcc18_mean  mfcc19_mean  mfcc20_mean
# 0        -8.990259     1.595329    -6.731744     4.317326
# 1        -7.328859     0.171362    -5.767624     3.249825
# 2        -7.587147     0.172193    -5.444875     1.197923
# 3        -8.594354    -0.271126    -5.592191    -0.288590
# 4        -9.315182    -3.543423    -5.760088     2.120627
# ...            ...          ...          ...          ...
# 79935     4.513030     4.309551     9.335838     4.856527
# 79936     1.916095     2.931519     7.093570     5.723800
# 79937     4.368050     4.368290     7.466063     1.732873
# 79938     1.273448     4.322249     9.085366     6.584610
# 79939     8.151299     8.260559     6.523771     3.882302
#
# [79940 rows x 29 columns]

# %%
import seaborn as sns
sns.pairplot(X)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-10802b88b195> in <module>
#       1 import seaborn as sns
# ----> 2 sns.pairplot(X)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2124     diag_kws.setdefault("legend", False)
#    2125     if diag_kind == "hist":
# -> 2126         grid.map_diag(histplot, **diag_kws)
#    2127     elif diag_kind == "kde":
#    2128         diag_kws.setdefault("fill", True)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1476             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1477             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1478             func(x=vector, **plot_kwargs)
#    1479             ax.legend_ = None
#    1480
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1473             estimate_kws=estimate_kws,
#    1474             line_kws=line_kws,
# -> 1475             **kwargs,
#    1476         )
#    1477
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     569                     bottom,
#     570                     align="edge",
# --> 571                     **artist_kws,
#     572                 )
#     573                 for bar in artists:
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2427                 edgecolor=e,
#    2428                 linewidth=lw,
# -> 2429                 label='_nolegend_',
#    2430                 )
#    2431             r.update(kwargs)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     705         """
#     706
# --> 707         Patch.__init__(self, **kwargs)
#     708
#     709         self._x0 = xy[0]
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      70             antialiased = mpl.rcParams['patch.antialiased']
#      71
# ---> 72         self._hatch_color = colors.to_rgba(mpl.rcParams['hatch.color'])
#      73         self._fill = True  # needed for set_facecolor call
#      74         if color is not None:
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     165     """
#     166     # Special-case nth color syntax because it should not be cached.
# --> 167     if _is_nth_color(c):
#     168         from matplotlib import rcParams
#     169         prop_cycler = rcParams['axes.prop_cycle']
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/colors.py in _is_nth_color(c)
#     113
#     114
# --> 115 def _is_nth_color(c):
#     116     """Return whether *c* can be interpreted as an item in the color cycle."""
#     117     return isinstance(c, str) and re.match(r"\AC[0-9]+\Z", c)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f89dd22e1e0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1294         if minor:
#    1295             return self.get_minorticklabels()
# -> 1296         return self.get_majorticklabels()
#    1297
#    1298     def get_majorticklines(self):
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1250     def get_majorticklabels(self):
#    1251         'Return a list of Text instances for the major ticklabels.'
# -> 1252         ticks = self.get_major_ticks()
#    1253         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1254         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1409         while len(self.majorTicks) < numticks:
#    1410             # Update the new tick label properties from the old.
# -> 1411             tick = self._get_tick(major=True)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
# --> 161         self.label1 = self._get_text1()
#     162         self.label2 = self._get_text2()
#     163
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/axis.py in _get_text1(self)
#     434             color=self._labelcolor,
#     435             verticalalignment=vert,
# --> 436             horizontalalignment=horiz,
#     437             )
#     438         t.set_transform(trans)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     166         self._linespacing = linespacing
#     167         self.set_rotation_mode(rotation_mode)
# --> 168         self.update(kwargs)
#     169
#     170     def update(self, kwargs):
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     175         sentinel = object()  # bbox can be None, so use another sentinel.
#     176         bbox = kwargs.pop("bbox", sentinel)
# --> 177         super().update(kwargs)
#     178         if bbox is not sentinel:
#     179             self.set_bbox(bbox)
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     971                 return func(v)
#     972
# --> 973         with cbook._setattr_cm(self, eventson=False):
#     974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#
# /opt/anaconda3/envs/AKpython/lib/python3.6/contextlib.py in __enter__(self)
#      77         return self.__class__(self.func, self.args, self.kwds)
#      78
# ---> 79     def __enter__(self):
#      80         try:
#      81             return next(self.gen)
#
# KeyboardInterrupt:

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (79940, 29) (79940,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ### With unscaled data

# %%
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.33238262029855725
# Testing Data Score: 0.3394545909432074
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#        Prediction         Actual
# 48999  Electronic     Electronic
# 40625  Electronic           Rock
# 27463  Electronic        Hip-Hop
# 35111  Electronic  International
# 56327  Electronic  International
# ...           ...            ...
# 58616  Electronic     Electronic
# 27197  Electronic   Instrumental
# 52080  Electronic           Rock
# 73117  Electronic           Folk
# 53820  Electronic   Instrumental
#
# [19985 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.28      0.27      0.28      2407
#  Experimental       0.25      0.12      0.16      2411
#          Folk       0.33      0.53      0.41      2487
#       Hip-Hop       0.39      0.40      0.40      2566
#  Instrumental       0.42      0.43      0.42      2490
# International       0.36      0.34      0.35      2563
#           Pop       0.15      0.03      0.05      2516
#          Rock       0.34      0.58      0.43      2545
#
#      accuracy                           0.34     19985
#     macro avg       0.31      0.34      0.31     19985
#  weighted avg       0.32      0.34      0.31     19985

# %% [markdown]
# ### With Scaled Data

# %%
# Create a StandardScaler() model and fit it to the training data
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train_scaled, y_train)
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.4111083312484363
# Testing Data Score: 0.415061295971979
# /opt/anaconda3/envs/AKpython/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
predictions = classifier.predict(X_test_scaled)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})
# Out:
#           Prediction         Actual
# 48999           Rock     Electronic
# 40625           Rock           Rock
# 27463            Pop        Hip-Hop
# 35111  International  International
# 56327     Electronic  International
# ...              ...            ...
# 58616        Hip-Hop     Electronic
# 27197           Rock   Instrumental
# 52080  International           Rock
# 73117           Folk           Folk
# 53820   Instrumental   Instrumental
#
# [19985 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import r2_score
y_pred = classifier.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
# Out:
#                precision    recall  f1-score   support
#
#    Electronic       0.37      0.41      0.39      2407
#  Experimental       0.33      0.21      0.25      2411
#          Folk       0.46      0.59      0.51      2487
#       Hip-Hop       0.46      0.47      0.47      2566
#  Instrumental       0.44      0.49      0.46      2490
# International       0.39      0.37      0.38      2563
#           Pop       0.28      0.12      0.16      2516
#          Rock       0.45      0.67      0.54      2545
#
#      accuracy                           0.42     19985
#     macro avg       0.40      0.41      0.40     19985
#  weighted avg       0.40      0.42      0.40     19985
