# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np  
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.random import sample_without_replacement
from sklearn.metrics import accuracy_score
from sklearn import preprocessing

# %%
df = pd.read_csv('../Project_4/data/model_data_3sec.csv')
df.head()
# Out:
#    Unnamed: 0      filename  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0           0  1-000574.mp3          0.381544         0.080175  0.249562
# 1           2  3-000574.mp3          0.484288         0.069135  0.253424
# 2           3  4-000574.mp3          0.425569         0.074970  0.256628
# 3           4  5-000574.mp3          0.468948         0.066816  0.265448
# 4           5  6-000574.mp3          0.392290         0.079841  0.271375
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.001513             1957.407156           39590.736312
# 1  0.001391             2766.351306          309436.169216
# 2  0.001596             2908.207536          157800.863917
# 3  0.001309             2618.340173          129314.679539
# 4  0.001388             2767.550410          159341.482509
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              2048.485350            25901.153997  ...   30.766535
# ...

# %%
# remove null values
df.dropna()
# Out:
#        Unnamed: 0       filename  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0               0   1-000574.mp3          0.381544         0.080175  0.249562
# 1               2   3-000574.mp3          0.484288         0.069135  0.253424
# 2               3   4-000574.mp3          0.425569         0.074970  0.256628
# 3               4   5-000574.mp3          0.468948         0.066816  0.265448
# 4               5   6-000574.mp3          0.392290         0.079841  0.271375
# ...           ...            ...               ...              ...       ...
# 71941       79935   6-155066.mp3          0.457243         0.066993  0.243057
# 71942       79936   7-155066.mp3          0.447897         0.071476  0.234766
# 71943       79937   8-155066.mp3          0.444989         0.068753  0.230987
# 71944       79938   9-155066.mp3          0.485998         0.070497  0.233158
# 71945       79939  10-155066.mp3          0.528556         0.065992  0.244644
#
# ...

# %%
df.drop('filename', axis =1)
# Out:
#        Unnamed: 0  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0               0          0.381544         0.080175  0.249562  0.001513
# 1               2          0.484288         0.069135  0.253424  0.001391
# 2               3          0.425569         0.074970  0.256628  0.001596
# 3               4          0.468948         0.066816  0.265448  0.001309
# 4               5          0.392290         0.079841  0.271375  0.001388
# ...           ...               ...              ...       ...       ...
# 71941       79935          0.457243         0.066993  0.243057  0.000386
# 71942       79936          0.447897         0.071476  0.234766  0.000319
# 71943       79937          0.444989         0.068753  0.230987  0.000125
# 71944       79938          0.485998         0.070497  0.233158  0.000335
# 71945       79939          0.528556         0.065992  0.244644  0.000123
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# ...

# %%
df= df[df.columns.drop(list(df.filter(regex='var')))]

# %%
clean_df = df.loc[(df['label']== 'Hip-Hop')|(df['label'] == 'Rock')]
clean_df
# Out:
#        Unnamed: 0       filename  chroma_stft_mean  rms_mean  \
# 0               0   1-000574.mp3          0.381544  0.249562
# 1               2   3-000574.mp3          0.484288  0.253424
# 2               3   4-000574.mp3          0.425569  0.256628
# 3               4   5-000574.mp3          0.468948  0.265448
# 4               5   6-000574.mp3          0.392290  0.271375
# ...           ...            ...               ...       ...
# 71941       79935   6-155066.mp3          0.457243  0.243057
# 71942       79936   7-155066.mp3          0.447897  0.234766
# 71943       79937   8-155066.mp3          0.444989  0.230987
# 71944       79938   9-155066.mp3          0.485998  0.233158
# 71945       79939  10-155066.mp3          0.528556  0.244644
#
#        spectral_centroid_mean  spectral_bandwidth_mean  rolloff_mean  \
# 0                 1957.407156              2048.485350   3585.029860
# 1                 2766.351306              2542.654962   5738.018893
# ...

# %%
# converting string labels into numbers
le = preprocessing.LabelEncoder()
X = clean_df.drop(['label','filename'], axis = 1)
y = le.fit_transform(clean_df.label.values)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Scaling the X data by using StandardScaler()
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-0.70518847, -1.12958616, -0.58735858, ..., -0.70584547,
#         -1.4010775 , -0.20851806],
#        [-0.07703555,  1.17752696,  0.82657941, ...,  0.07387374,
#          0.83546826,  0.84699828],
#        [-1.66951835, -1.4153507 , -1.63047596, ...,  0.13018517,
#         -1.85099189, -1.72268114],
#        ...,
#        [ 1.66982783, -2.0666343 , -1.08261299, ...,  0.03640287,
#         -0.46506012,  1.03585891],
#        [ 1.49151762,  0.41289062,  0.60828713, ...,  0.35410065,
#         -0.22147676, -0.06603392],
#        [-1.36923585,  0.12370921, -0.09398162, ...,  0.24991739,
#          0.94828383,  1.65344061]])

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
#Making prediction 
prediction = classifier.predict(X_test_scaled)
prediction
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
y_true = y_test
y_pred = classifier.predict(X_test_scaled)
cnf_matrix = metrics.confusion_matrix(y_true, y_pred)
cnf_matrix
# Out:
# array([[1910,  395],
#        [ 343, 1849]], dtype=int64)

# %% [markdown]
# #### Visualizing Confusion Matrix using Heatmap

# %%
# Visualizing confusion matrix
import seaborn as sns
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %% [markdown]
# #### Confusion Matrix Evaluation Metrics

# %%
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Training Data Score: 0.8317272053372868
# Accuracy: 0.8358905937291528

# %% [markdown]
# The classification rate is increased to 89%, which is considered as a good accuracy

# %% [markdown]
# #### ROC Curve

# %%
y_pred_proba = classifier.predict_proba(X_test_scaled)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# AUC score for the case is 0.95

# %%
from joblib import dump, load
dump(classifier, 'Model/3_sec-model_lr2.joblib')
# Out:
# ['Model/3_sec-model_lr2.joblib']
